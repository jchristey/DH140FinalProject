# %%
import pandas as pd

# %%
MatHealth = pd.read_csv('https://data.cdc.gov/api/views/nfuu-hu6j/rows.csv?accessType=DOWNLOAD')

# %%
MatHealth
# Out:
#                                               INDICATOR  INDICATOR_NUM  \
# 0     Infant, neonatal, postneonatal, fetal, and per...              1
# 1     Infant, neonatal, postneonatal, fetal, and per...              1
# 2     Infant, neonatal, postneonatal, fetal, and per...              1
# 3     Infant, neonatal, postneonatal, fetal, and per...              1
# 4     Infant, neonatal, postneonatal, fetal, and per...              1
# ...                                                 ...            ...
# 2683  Infant, neonatal, postneonatal, fetal, and per...              1
# 2684  Infant, neonatal, postneonatal, fetal, and per...              1
# 2685  Infant, neonatal, postneonatal, fetal, and per...              1
# 2686  Infant, neonatal, postneonatal, fetal, and per...              1
# 2687  Infant, neonatal, postneonatal, fetal, and per...              1
#
#                                                    UNIT  UNIT_NUM  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
MatHealth.plot(x = 'Year', y = 'Estimate', kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# ...
